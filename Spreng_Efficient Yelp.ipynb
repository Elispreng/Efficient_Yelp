# %% [markdown]
# # Set up project

# %%
# install packages
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\elizabeth spreng\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\elizabeth spreng\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## load API credentials

# %%
# create yelp API
with open("C:\\Users\\Elizabeth Spreng\\.secret\\yelp_api.json") as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# create YELP variable with timeout
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

# %% [markdown]
# # Define Search

# %%
# set our API call parameters and filename before the first call
location = 'New Orleans, LA 70130'
term = 'cajun'

# %%
# create location split
location.split(',')[0]
# Out:
# 'New Orleans'

# %%
## Specify folder
## Specify foldler for saving data

FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check JSON
JSON_FILE
# Out:
# 'Data/New Orleans-cajun.json'

# %% [markdown]
# ## Check for JSON file

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([],f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/New Orleans-cajun.json not found. Saving empty list to file.

# %% [markdown]
# # Make first API call

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp_api.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
# Find out how many.
results['total']
# Out:
# 411

# %% [markdown]
# - There are 411 results

# %%
# Where are the results
results['region']
# Out:
# {'center': {'longitude': -90.07226943969727, 'latitude': 29.93886784760904}}

# %%
results['businesses']
# Out:
# [{'id': 'SJIQFKTW6uUsOo29w9IHxw',
#   'alias': 'mambos-new-orleans',
#   'name': "Mambo's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tarz6Y_fjU42sDk_SwBUPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mambos-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 1854,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.95668, 'longitude': -90.06772},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '411 Bourbon St',
#    'address2': '',
#    'address3': None,
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['411 Bourbon St', 'New Orleans, LA 70130']},
#   'phone': '+15044073717',
#   'display_phone': '(504) 407-3717',
#   'distance': 2028.724441040581},
#  {'id': '6a4gLLFSgr-Q6CZXDLzBGQ',
#   'alias': 'cochon-new-orleans-3',
#   'name': 'Cochon',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Z30o0oDp3L4p6MfeeGzxMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cochon-new-orleans-3?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 4746,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.94226, 'longitude': -90.06713},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '930 Tchoupitoulas St',
#    'address2': '',
#    'address3': None,
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['930 Tchoupitoulas St', 'New Orleans, LA 70130']},
#   'phone': '+15045882123',
#   'display_phone': '(504) 588-2123',
#   'distance': 613.3538352557024},
#  {'id': 'NHdE_ObFj7OjQBB3jjqBNQ',
#   'alias': 'lula-restaurant-distillery-new-orleans-2',
#   'name': 'Lula Restaurant Distillery',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wogeWy3gb6wiDpsljSf5eA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lula-restaurant-distillery-new-orleans-2?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 788,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'distilleries', 'title': 'Distilleries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.9385946, 'longitude': -90.0755526},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1532 St Charles Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1532 St Charles Ave', 'New Orleans, LA 70130']},
#   'phone': '+15042677624',
#   'display_phone': '(504) 267-7624',
#   'distance': 325.8253851761191},
#  {'id': 'ac1AeYqs8Z4_e2X5M3if2A',
#   'alias': 'oceana-grill-new-orleans-4',
#   'name': 'Oceana Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xW9nO4DC_N-nYO9_jq9qdg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oceana-grill-new-orleans-4?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 8440,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.956231, 'longitude': -90.067563},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '739 Conti St',
#    'address2': '',
#    'address3': None,
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['739 Conti St', 'New Orleans, LA 70130']},
#   'phone': '+15045256002',
#   'display_phone': '(504) 525-6002',
#   'distance': 1983.2288887138077},
#  {'id': 'swVdc9piXvG0AXwL-F0GfQ',
#   'alias': 'gallier-restaurant-and-oyster-bar-new-orleans',
#   'name': 'Gallier Restaurant & Oyster Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IUq5PVNVXb7LjPzhrbw0KQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gallier-restaurant-and-oyster-bar-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 1113,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9533, 'longitude': -90.07077},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '129 Carondelet St',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70112',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['129 Carondelet St', 'New Orleans, LA 70112']},
#   'phone': '+15042675672',
#   'display_phone': '(504) 267-5672',
#   'distance': 1613.7474432358583},
#  {'id': 'VQcCL9PiNL_wkGf-uF3fjg',
#   'alias': 'royal-house-new-orleans',
#   'name': 'Royal House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/41QZ_g7_nyNN7Jny8gRpXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/royal-house-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 5472,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.956473230039563,
#    'longitude': -90.066386050993},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '441 Royal St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['441 Royal St', 'New Orleans, LA 70130']},
#   'phone': '+15045282601',
#   'display_phone': '(504) 528-2601',
#   'distance': 2038.0449906954723},
#  {'id': 'WO-ofNAvSuJpdRt9Auon6w',
#   'alias': 'heard-dat-kitchen-new-orleans',
#   'name': 'Heard Dat Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8IuxBb6pF1SEvMrh9MfcMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/heard-dat-kitchen-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 623,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9437066, 'longitude': -90.0861294},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2520 Felicity St',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70113',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['2520 Felicity St', 'New Orleans, LA 70113']},
#   'phone': '+15045104248',
#   'display_phone': '(504) 510-4248',
#   'distance': 1463.6707041283664},
#  {'id': 'A0DYN5wxygYnX_sL3HygvA',
#   'alias': 'gris-gris-new-orleans',
#   'name': 'Gris-Gris',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nC7HpoGt3_VOOOc3rzjFBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gris-gris-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 714,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.93179, 'longitude': -90.07339},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1800 Magazine St',
#    'address2': '',
#    'address3': None,
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1800 Magazine St', 'New Orleans, LA 70130']},
#   'phone': '+15042720241',
#   'display_phone': '(504) 272-0241',
#   'distance': 796.1591668870735},
#  {'id': 'qb28j-FNX1_6xm7u372TZA',
#   'alias': 'gumbo-shop-new-orleans-2',
#   'name': 'Gumbo Shop',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jHXYUXoX4FHeEiLEH5Cz7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gumbo-shop-new-orleans-2?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 4335,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.957692211278957,
#    'longitude': -90.06452299790816},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '630 Saint Peter St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70116',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['630 Saint Peter St', 'New Orleans, LA 70116']},
#   'phone': '+15045251486',
#   'display_phone': '(504) 525-1486',
#   'distance': 2222.252759349307},
#  {'id': 'BHnCAV4_hgqgNZGdfXNJkA',
#   'alias': 'cajun-seafood-new-orleans-2',
#   'name': 'Cajun Seafood',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V3BwitZg2-X7gScHEGlW3g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cajun-seafood-new-orleans-2?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 1063,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'french', 'title': 'French'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.97112, 'longitude': -90.06769},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1479 N Claiborne Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70116',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1479 N Claiborne Ave', 'New Orleans, LA 70116']},
#   'phone': '+15049486000',
#   'display_phone': '(504) 948-6000',
#   'distance': 3621.7385309929336},
#  {'id': 'RGXb-3iUuaORNWB_nt_RcQ',
#   'alias': 'galliano-restaurant-new-orleans',
#   'name': 'Galliano Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VdbNi2DvOVzQa4eILcXSAA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/galliano-restaurant-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 799,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.944331, 'longitude': -90.065402},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '200 Julia St',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['200 Julia St', 'New Orleans, LA 70130']},
#   'phone': '+15042185753',
#   'display_phone': '(504) 218-5753',
#   'distance': 904.258861202971},
#  {'id': '-ojG1NfFYuHN_oGsGK1W8Q',
#   'alias': 'the-little-easy-new-orleans',
#   'name': 'The Little Easy',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H2AdbDWbAk5ZoagOhf5A9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-little-easy-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 82,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.94566, 'longitude': -90.0714},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '634 Julia St',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['634 Julia St', 'New Orleans, LA 70130']},
#   'phone': '+15045818452',
#   'display_phone': '(504) 581-8452',
#   'distance': 758.3778477236544},
#  {'id': 'EME5hqQLjBD7e2cLryupbA',
#   'alias': 'mr-eds-oyster-bar-bienville-new-orleans-2',
#   'name': "Mr Ed's Oyster Bar - Bienville",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zbjKOhIzHG5UCha15cjuTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mr-eds-oyster-bar-bienville-new-orleans-2?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 1594,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9537198203863,
#    'longitude': -90.0659187477944},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '512 Bienville St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['512 Bienville St', 'New Orleans, LA 70130']},
#   'phone': '+15043094848',
#   'display_phone': '(504) 309-4848',
#   'distance': 1756.3805627792801},
#  {'id': '_C7QiQQc47AOEv4PE3Kong',
#   'alias': 'commanders-palace-new-orleans-2',
#   'name': "Commander's Palace",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xkfUmc-sWeL7I0ZpU7UzUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/commanders-palace-new-orleans-2?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 5308,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9287354417977, 'longitude': -90.084195609787},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '1403 Washington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1403 Washington Ave', 'New Orleans, LA 70130']},
#   'phone': '+15048998221',
#   'display_phone': '(504) 899-8221',
#   'distance': 1609.3811221001724},
#  {'id': 'GBTPC53ZrG1ZBY3DT8Mbcw',
#   'alias': 'luke-new-orleans-3',
#   'name': 'Luke',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1GCl8BzZ_00Oqp27PtqpCg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/luke-new-orleans-3?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 4878,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'german', 'title': 'German'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.9507416316034,
#    'longitude': -90.0704155423279},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '333 Saint Charles Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['333 Saint Charles Ave', 'New Orleans, LA 70130']},
#   'phone': '+15043782840',
#   'display_phone': '(504) 378-2840',
#   'distance': 1332.3314453644387},
#  {'id': 'S2Ho8yLxhKAa26pBAm6rxA',
#   'alias': 'creole-house-restaurant-and-oyster-bar-new-orleans',
#   'name': 'Creole House Restaurant & Oyster Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0U07KJ1SssJwewLS8erDBw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/creole-house-restaurant-and-oyster-bar-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 2047,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.95214, 'longitude': -90.06705},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '509 Canal St',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['509 Canal St', 'New Orleans, LA 70130']},
#   'phone': '+15043232109',
#   'display_phone': '(504) 323-2109',
#   'distance': 1564.3404160910354},
#  {'id': 'iSRTaT9WngzB8JJ2YKJUig',
#   'alias': 'mothers-restaurant-new-orleans',
#   'name': "Mother's Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VL-XncfKyu6vzy4hEyQS6g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mothers-restaurant-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 5646,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.94903, 'longitude': -90.06721},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '401 Poydras St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['401 Poydras St', 'New Orleans, LA 70130']},
#   'phone': '+15045239656',
#   'display_phone': '(504) 523-9656',
#   'distance': 1239.6003161423487},
#  {'id': 'oDETvkVkHw7CjZj7ZOZFOQ',
#   'alias': 'cajun-mikes-pub-and-grub-new-orleans',
#   'name': "Cajun Mike's Pub & Grub",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RrAZCyB3l7oX9GOlu88yLg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cajun-mikes-pub-and-grub-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 808,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.95396, 'longitude': -90.0712099},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '116 Baronne St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70112',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['116 Baronne St', 'New Orleans, LA 70112']},
#   'phone': '+15045660055',
#   'display_phone': '(504) 566-0055',
#   'distance': 1655.8895684603838},
#  {'id': '75FY8ZQx5nOWP0VFmNvWfw',
#   'alias': 'atchafalaya-restaurant-new-orleans',
#   'name': 'Atchafalaya Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/79CksDOOLNCwzgF74n-rFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/atchafalaya-restaurant-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 2204,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9212715, 'longitude': -90.0878562},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '901 Louisiana Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70115',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['901 Louisiana Ave', 'New Orleans, LA 70115']},
#   'phone': '+15048919626',
#   'display_phone': '(504) 891-9626',
#   'distance': 2466.666634640761},
#  {'id': 'VaO-VW3e1kARkU9bP1E7Fw',
#   'alias': 'felixs-restaurant-and-oyster-bar-new-orleans',
#   'name': "Felix's Restaurant & Oyster Bar",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HL8tZuyLJ0Jm_JojzfMoqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/felixs-restaurant-and-oyster-bar-new-orleans?adjust_creative=egnwJc6-rjfQ1ZoIx6QkpQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=egnwJc6-rjfQ1ZoIx6QkpQ',
#   'review_count': 4404,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.9546804305772,
#    'longitude': -90.0689453974164},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '739 Iberville St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['739 Iberville St', 'New Orleans, LA 70130']},
#   'phone': '+15045224440',
#   'display_phone': '(504) 522-4440',
#   'distance': 1787.2073636840732}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                              alias  \
# 0   SJIQFKTW6uUsOo29w9IHxw                                 mambos-new-orleans
# 1   6a4gLLFSgr-Q6CZXDLzBGQ                               cochon-new-orleans-3
# 2   NHdE_ObFj7OjQBB3jjqBNQ           lula-restaurant-distillery-new-orleans-2
# 3   ac1AeYqs8Z4_e2X5M3if2A                         oceana-grill-new-orleans-4
# 4   swVdc9piXvG0AXwL-F0GfQ      gallier-restaurant-and-oyster-bar-new-orleans
# 5   VQcCL9PiNL_wkGf-uF3fjg                            royal-house-new-orleans
# 6   WO-ofNAvSuJpdRt9Auon6w                      heard-dat-kitchen-new-orleans
# 7   A0DYN5wxygYnX_sL3HygvA                              gris-gris-new-orleans
# 8   qb28j-FNX1_6xm7u372TZA                           gumbo-shop-new-orleans-2
# 9   BHnCAV4_hgqgNZGdfXNJkA                        cajun-seafood-new-orleans-2
# 10  RGXb-3iUuaORNWB_nt_RcQ                    galliano-restaurant-new-orleans
# 11  -ojG1NfFYuHN_oGsGK1W8Q                        the-little-easy-new-orleans
# 12  EME5hqQLjBD7e2cLryupbA          mr-eds-oyster-bar-bienville-new-orleans-2
# 13  _C7QiQQc47AOEv4PE3Kong                    commanders-palace-new-orleans-2
# 14  GBTPC53ZrG1ZBY3DT8Mbcw                                 luke-new-orleans-3
# 15  S2Ho8yLxhKAa26pBAm6rxA  creole-house-restaurant-and-oyster-bar-new-orl...
# 16  iSRTaT9WngzB8JJ2YKJUig                     mothers-restaurant-new-orleans
# 17  oDETvkVkHw7CjZj7ZOZFOQ               cajun-mikes-pub-and-grub-new-orleans
# 18  75FY8ZQx5nOWP0VFmNvWfw                 atchafalaya-restaurant-new-orleans
# 19  VaO-VW3e1kARkU9bP1E7Fw       felixs-restaurant-and-oyster-bar-new-orleans
#
#                                     name  \
# 0                                Mambo's
# 1                                 Cochon
# 2             Lula Restaurant Distillery
# 3                           Oceana Grill
# 4        Gallier Restaurant & Oyster Bar
# 5                            Royal House
# 6                      Heard Dat Kitchen
# 7                              Gris-Gris
# 8                             Gumbo Shop
# 9                          Cajun Seafood
# 10                   Galliano Restaurant
# 11                       The Little Easy
# 12        Mr Ed's Oyster Bar - Bienville
# 13                    Commander's Palace
# 14                                  Luke
# 15  Creole House Restaurant & Oyster Bar
# 16                   Mother's Restaurant
# 17               Cajun Mike's Pub & Grub
# 18                Atchafalaya Restaurant
# 19       Felix's Restaurant & Oyster Bar
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/tarz6Y...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/Z30o0o...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/wogeWy...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/xW9nO4...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/IUq5PV...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/41QZ_g...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/8IuxBb...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/nC7Hpo...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/jHXYUX...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/V3Bwit...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/VdbNi2...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/H2AdbD...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/zbjKOh...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/xkfUmc...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/1GCl8B...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/0U07KJ...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/VL-Xnc...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/RrAZCy...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/79CksD...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/HL8tZu...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/mambos-new-orleans?ad...          1854
# 1   https://www.yelp.com/biz/cochon-new-orleans-3?...          4746
# 2   https://www.yelp.com/biz/lula-restaurant-disti...           788
# 3   https://www.yelp.com/biz/oceana-grill-new-orle...          8440
# 4   https://www.yelp.com/biz/gallier-restaurant-an...          1113
# 5   https://www.yelp.com/biz/royal-house-new-orlea...          5472
# 6   https://www.yelp.com/biz/heard-dat-kitchen-new...           623
# 7   https://www.yelp.com/biz/gris-gris-new-orleans...           714
# 8   https://www.yelp.com/biz/gumbo-shop-new-orlean...          4335
# 9   https://www.yelp.com/biz/cajun-seafood-new-orl...          1063
# 10  https://www.yelp.com/biz/galliano-restaurant-n...           799
# 11  https://www.yelp.com/biz/the-little-easy-new-o...            82
# 12  https://www.yelp.com/biz/mr-eds-oyster-bar-bie...          1594
# 13  https://www.yelp.com/biz/commanders-palace-new...          5308
# 14  https://www.yelp.com/biz/luke-new-orleans-3?ad...          4878
# 15  https://www.yelp.com/biz/creole-house-restaura...          2047
# 16  https://www.yelp.com/biz/mothers-restaurant-ne...          5646
# 17  https://www.yelp.com/biz/cajun-mikes-pub-and-g...           808
# 18  https://www.yelp.com/biz/atchafalaya-restauran...          2204
# 19  https://www.yelp.com/biz/felixs-restaurant-and...          4404
#
#                                            categories  rating  \
# 0   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 1   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 2   [{'alias': 'southern', 'title': 'Southern'}, {...     4.0
# 3   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 4   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 5   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 6   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 7   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 8       [{'alias': 'cajun', 'title': 'Cajun/Creole'}]     4.0
# 9   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 10  [{'alias': 'southern', 'title': 'Southern'}, {...     4.5
# 11  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 12  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 13  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 14  [{'alias': 'french', 'title': 'French'}, {'ali...     4.0
# 15  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 16  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     3.5
# 17  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 18  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 19  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
#
#                                           coordinates        transactions  \
# 0      {'latitude': 29.95668, 'longitude': -90.06772}  [pickup, delivery]
# 1      {'latitude': 29.94226, 'longitude': -90.06713}          [delivery]
# 2   {'latitude': 29.9385946, 'longitude': -90.0755...          [delivery]
# 3    {'latitude': 29.956231, 'longitude': -90.067563}  [pickup, delivery]
# 4       {'latitude': 29.9533, 'longitude': -90.07077}          [delivery]
# 5   {'latitude': 29.956473230039563, 'longitude': ...          [delivery]
# 6   {'latitude': 29.9437066, 'longitude': -90.0861...  [pickup, delivery]
# 7      {'latitude': 29.93179, 'longitude': -90.07339}          [delivery]
# 8   {'latitude': 29.957692211278957, 'longitude': ...          [delivery]
# 9      {'latitude': 29.97112, 'longitude': -90.06769}          [delivery]
# 10   {'latitude': 29.944331, 'longitude': -90.065402}          [delivery]
# 11      {'latitude': 29.94566, 'longitude': -90.0714}  [pickup, delivery]
# 12  {'latitude': 29.9537198203863, 'longitude': -9...          [delivery]
# 13  {'latitude': 29.9287354417977, 'longitude': -9...          [delivery]
# 14  {'latitude': 29.9507416316034, 'longitude': -9...          [delivery]
# 15     {'latitude': 29.95214, 'longitude': -90.06705}          [delivery]
# 16     {'latitude': 29.94903, 'longitude': -90.06721}          [delivery]
# 17   {'latitude': 29.95396, 'longitude': -90.0712099}          [delivery]
# 18  {'latitude': 29.9212715, 'longitude': -90.0878...          [delivery]
# 19  {'latitude': 29.9546804305772, 'longitude': -9...          [delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '411 Bourbon St', 'address2': '',...  +15044073717
# 1     $$  {'address1': '930 Tchoupitoulas St', 'address2...  +15045882123
# 2     $$  {'address1': '1532 St Charles Ave', 'address2'...  +15042677624
# 3     $$  {'address1': '739 Conti St', 'address2': '', '...  +15045256002
# 4     $$  {'address1': '129 Carondelet St', 'address2': ...  +15042675672
# 5     $$  {'address1': '441 Royal St', 'address2': '', '...  +15045282601
# 6     $$  {'address1': '2520 Felicity St', 'address2': N...  +15045104248
# 7     $$  {'address1': '1800 Magazine St', 'address2': '...  +15042720241
# 8     $$  {'address1': '630 Saint Peter St', 'address2':...  +15045251486
# 9     $$  {'address1': '1479 N Claiborne Ave', 'address2...  +15049486000
# 10   $$$  {'address1': '200 Julia St', 'address2': None,...  +15042185753
# 11    $$  {'address1': '634 Julia St', 'address2': None,...  +15045818452
# 12    $$  {'address1': '512 Bienville St', 'address2': '...  +15043094848
# 13   $$$  {'address1': '1403 Washington Ave', 'address2'...  +15048998221
# 14    $$  {'address1': '333 Saint Charles Ave', 'address...  +15043782840
# 15    $$  {'address1': '509 Canal St', 'address2': None,...  +15043232109
# 16    $$  {'address1': '401 Poydras St', 'address2': '',...  +15045239656
# 17     $  {'address1': '116 Baronne St', 'address2': '',...  +15045660055
# 18   $$$  {'address1': '901 Louisiana Ave', 'address2': ...  +15048919626
# 19    $$  {'address1': '739 Iberville St', 'address2': '...  +15045224440
#
#      display_phone     distance
# 0   (504) 407-3717  2028.724441
# 1   (504) 588-2123   613.353835
# 2   (504) 267-7624   325.825385
# 3   (504) 525-6002  1983.228889
# 4   (504) 267-5672  1613.747443
# 5   (504) 528-2601  2038.044991
# 6   (504) 510-4248  1463.670704
# 7   (504) 272-0241   796.159167
# 8   (504) 525-1486  2222.252759
# 9   (504) 948-6000  3621.738531
# 10  (504) 218-5753   904.258861
# 11  (504) 581-8452   758.377848
# 12  (504) 309-4848  1756.380563
# 13  (504) 899-8221  1609.381122
# 14  (504) 378-2840  1332.331445
# 15  (504) 323-2109  1564.340416
# 16  (504) 523-9656  1239.600316
# 17  (504) 566-0055  1655.889568
# 18  (504) 891-9626  2466.666635
# 19  (504) 522-4440  1787.207364

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages

# %%
# Use math.ceil to round up for the total number of pages of results.
import time, math

n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 21

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp_api.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results,f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print('[!] ERROR: ', e)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %% [markdown]
# # Open JSON file with Pandas

# %%
#create dataframe
df = pd.read_json(JSON_FILE)

# %%
#look at the dataframe
df.head()
# Out:
#                        id                                          alias  \
# 0  6a4gLLFSgr-Q6CZXDLzBGQ                           cochon-new-orleans-3
# 1  NHdE_ObFj7OjQBB3jjqBNQ       lula-restaurant-distillery-new-orleans-2
# 2  ac1AeYqs8Z4_e2X5M3if2A                     oceana-grill-new-orleans-4
# 3  swVdc9piXvG0AXwL-F0GfQ  gallier-restaurant-and-oyster-bar-new-orleans
# 4  VQcCL9PiNL_wkGf-uF3fjg                        royal-house-new-orleans
#
#                               name  \
# 0                           Cochon
# 1       Lula Restaurant Distillery
# 2                     Oceana Grill
# 3  Gallier Restaurant & Oyster Bar
# 4                      Royal House
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/Z30o0o...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/wogeWy...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/xW9nO4...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/IUq5PV...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/41QZ_g...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/cochon-new-orleans-3?...          4746
# 1  https://www.yelp.com/biz/lula-restaurant-disti...           788
# 2  https://www.yelp.com/biz/oceana-grill-new-orle...          8440
# 3  https://www.yelp.com/biz/gallier-restaurant-an...          1113
# 4  https://www.yelp.com/biz/royal-house-new-orlea...          5472
#
#                                           categories  rating  \
# 0  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 1  [{'alias': 'southern', 'title': 'Southern'}, {...     4.0
# 2  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 3  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 4  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
#
#                                          coordinates        transactions  \
# 0     {'latitude': 29.94226, 'longitude': -90.06713}          [delivery]
# 1  {'latitude': 29.9385946, 'longitude': -90.0755...          [delivery]
# 2   {'latitude': 29.956231, 'longitude': -90.067563}  [pickup, delivery]
# 3      {'latitude': 29.9533, 'longitude': -90.07077}          [delivery]
# 4  {'latitude': 29.956473230039563, 'longitude': ...          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '930 Tchoupitoulas St', 'address2...  +15045882123
# 1    $$  {'address1': '1532 St Charles Ave', 'address2'...  +15042677624
# 2    $$  {'address1': '739 Conti St', 'address2': '', '...  +15045256002
# 3    $$  {'address1': '129 Carondelet St', 'address2': ...  +15042675672
# 4    $$  {'address1': '441 Royal St', 'address2': '', '...  +15045282601
#
#     display_phone     distance
# 0  (504) 588-2123   613.353835
# 1  (504) 267-7624   325.825385
# 2  (504) 525-6002  1983.228889
# 3  (504) 267-5672  1613.747443
# 4  (504) 528-2601  2038.044991

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/New Orleans-cajun.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression='gzip', index=False)

# %% [markdown]
# ## Compare sizes

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 408,685 Bytes
# CSV.GZ FILE: 57,208 Bytes
# the csv.gz is 7.143843518389036 times smaller!
